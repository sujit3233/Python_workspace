# %%
city="pune"
print(city)
print(type(city))
print(id(city))
# Out:
# pune
# <class 'str'>
# 4429809968

# %%
roll_number=89
print(roll_number)
print(type(roll_number))
print(id(roll_number))
# Out:
# 89
# <class 'int'>
# 4323064544

# %%
data=89.9
print(data)
print(type(data))
print(id(data))
# Out:
# 89.9
# <class 'float'>
# 4421950320
