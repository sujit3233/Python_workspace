# %%
a = True
print(a)
print(type(a))
print(id(a))
# Out:
# True
# <class 'bool'>
# 4333222392

# %%
college="MIT"
print(college)
print(type(college))
print(id(college))
# Out:
# MIT
# <class 'str'>
# 4440120592

# %%
weather="sunny"
print(weather)
print(type(weather))
print(id(weather))
# Out:
# sunny
# <class 'str'>
# 4440344544
