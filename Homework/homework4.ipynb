# %%
score=98.7
print(score)
print(type(score))
print(id(score))
# Out:
# 98.7
# <class 'float'>
# 4466118576

# %%
a=90
b=89.89
print(a+b)
print(type(a+b))
print(id(a+b))
# Out:
# 179.89
# <class 'float'>
# 4460256368

# %%
c = False
print(c)
print(type(c))
print(id(c))
# Out:
# False
# <class 'bool'>
# 4359797208
