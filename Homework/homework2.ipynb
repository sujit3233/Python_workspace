# %%
a=5
b=66
print(a+b)
print(type(a+b))
print(id(a+b))
# Out:
# 71
# <class 'int'>
# 4387256480

# %%
name="Sujit"
print("My name is",name)
print(type(name))
print(id(name))
# Out:
# My name is Sujit
# <class 'str'>
# 4494482224

# %%
marks=89.9
print(marks)
print(type(marks))
print(id(marks))
# Out:
# 89.9
# <class 'float'>
# 4492440016
