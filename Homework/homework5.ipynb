# %%
tv_serial="tarak mehta ka ooltah chashmah"
print("TV Serial is:",tv_serial)
print("Type of tv_serial is:",type(tv_serial))
print("ID of tv_serial is:",id(tv_serial))
# Out:
# TV Serial is: tarak mehta ka ooltah chashmah
# Type of tv_serial is: <class 'str'>
# ID of tv_serial is: 4474006112

# %%
acount_balance=1000.50
print("Account Balance is:",acount_balance)
print("Type of acount_balance is:",type(acount_balance))
print("ID of acount_balance is:",id(acount_balance))
# Out:
# Account Balance is: 1000.5
# Type of acount_balance is: <class 'float'>
# ID of acount_balance is: 4466187120

# %%
id_data=1346
print("ID Data is:",id_data)
print("Type of id_data is:",type(id_data))
# Out:
# ID Data is: 1346
# Type of id_data is: <class 'int'>
